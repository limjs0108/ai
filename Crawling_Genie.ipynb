# %%
# !pip install selenium

from selenium import webdriver

from bs4 import BeautifulSoup as bs
# Out:
# Requirement already satisfied: selenium in c:\users\polim\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\polim\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\polim\anaconda3\lib\site-packages (from selenium) (0.19.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\polim\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: idna in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sortedcontainers in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: sniffio in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\polim\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\polim\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Requirement already satisfied: wsproto>=0.14 in c:\users\polim\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\polim\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\polim\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\polim\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\polim\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\polim\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://www.genie.co.kr/chart/top200')
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_4660/1973453846.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
html = driver.page_source
soup = bs(html)

# %%
songs = []
songs = soup.select('tr.list')
songs[0]
# Out:
# <tr class="list" songid="95990155">
# <td class="check"><input class="select-check" title="INVU" type="checkbox"/></td>
# <td class="number">1
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('82529386');return false;"><span class="mask"></span><img alt="INVU - The 3rd Album" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/082/529/386/82529386_1644820151763_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('95990155');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('95990155','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 INVU</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('56069675');return false;">태연 (TAEYEON)</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('95990155');" type="button">외</button>
# <ul class="list" id="RelationArtist_95990155"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('82529386');return false;">INVU - The 3rd Album</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('95990155;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('95990155;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_95990155" onclick="fnAddMyAlbumForm('#add_my_album_95990155' , '95990155' ,10, 10);return false;" songid="95990155" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('95990155');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_95990155">
# <a alt="INVU" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('95990155','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('95990155');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('95990155');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>

# %%
singer = songs[0].select('a.artist')[0].text.strip()
singer
# Out:
# '태연 (TAEYEON)'

# %%
title = songs[0].select('a.title')[0].text.strip()
title
# Out:
# 'INVU'

# %%
songs_data =[]
rank = 1
songs = soup.select('tr.list')

for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()
    songs_data.append([rank, title, singer])
    rank += 1
    
songs_data
# Out:
# [[1, 'INVU', '태연 (TAEYEON)'],
#  [2, '그래서 그래 (Feat. 윤하)', '에픽하이 (EPIK HIGH)'],
#  [3, '취중고백', '김민석 (멜로망스)'],
#  [4, '사랑은 늘 도망가', '임영웅'],
#  [5, '잊을 수 있을까', '노을'],
#  [6, '호랑수월가', '탑현'],
#  [7, 'abcdefu', 'GAYLE'],
#  [8, '회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)', 'sokodomo'],
#  [9, '다정히 내 이름을 부르면', '경서예지 & 전건호'],
#  [10, '눈이 오잖아 (Feat. 헤이즈)', '이무진'],
#  [11, 'ELEVEN', 'IVE (아이브)'],
#  [12, '리무진 (Feat. MINO) (Prod. by GRAY)', "BE'O (비오)"],
#  [13, 'Step Back', 'GOT the beat'],
#  [14, '서랍', '10CM'],
#  [15, 'strawberry moon', '아이유 (IU)'],
#  [16, '그런 밤 (Some Nights)', '태연 (TAEYEON)'],
#  [17, '이제 나만 믿어요', '임영웅'],
#  [18, 'Counting Stars (Feat. Beenzino)', "BE'O (비오)"],
#  [19, '신호등', '이무진'],
#  [20, '다시 사랑한다면 (김필 Ver.)', '임영웅'],
#  [21, 'Stay', 'The Kid LAROI & Justin Bieber'],
#  [22, '언제나 사랑해', '케이시 (Kassy)'],
#  [23, '겨울잠', '아이유 (IU)'],
#  [24, "Can't Control Myself", '태연 (TAEYEON)'],
#  [25, '별빛 같은 나의 사랑아', '임영웅'],
#  [26, '잊었니', '임영웅'],
#  [27, 'Next Level', 'aespa'],
#  [28, '그대라는 사치', '임영웅'],
#  [29, '끝사랑', '임영웅'],
#  [30, 'HERO', '임영웅'],
#  [31, 'Bk Love', '임영웅'],
#  [32, '흰눈', '먼데이 키즈 (Monday Kiz)'],
#  [33, '만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. by TOIL)', '베이식'],
#  [34, '문득', "BE'O (비오)"],
#  [35, 'Dreams Come True', 'aespa'],
#  [36, '어른아이 (Toddler)', '태연 (TAEYEON)'],
#  [37, 'Dilemma', 'Apink (에이핑크)'],
#  [38, '계단말고 엘리베이터', '임영웅'],
#  [39, 'Bad Habits', 'Ed Sheeran'],
#  [40, 'OHAYO MY NIGHT', '디핵 (D-Hack) & PATEKO'],
#  [41, '우리가 헤어져야 했던 이유', '비비 (BIBI)'],
#  [42, '바라만 본다', 'MSG워너비 (M.O.M)'],
#  [43, 'Butter', '방탄소년단'],
#  [44, '밤하늘의 별을 (2020)', '경서'],
#  [45, 'Set Myself On Fire', '태연 (TAEYEON)'],
#  [46, 'My Universe', 'Coldplay & 방탄소년단'],
#  [47, 'Savage', 'aespa'],
#  [48, '드라마', '아이유 (IU)'],
#  [49, 'Dynamite', '방탄소년단'],
#  [50, 'Permission to Dance', '방탄소년단']]

# %%
import pandas as pd
df = pd.DataFrame(songs_data,columns = ['순위','제목','가수'])
df
# Out:
#     순위                                                 제목  \
# 0    1                                               INVU
# 1    2                                  그래서 그래 (Feat. 윤하)
# 2    3                                               취중고백
# 3    4                                          사랑은 늘 도망가
# 4    5                                           잊을 수 있을까
# 5    6                                              호랑수월가
# 6    7                                            abcdefu
# 7    8         회전목마 (Feat. Zion.T & 원슈타인) (Prod. by Slom)
# 8    9                                      다정히 내 이름을 부르면
# 9   10                                 눈이 오잖아 (Feat. 헤이즈)
# 10  11                                             ELEVEN
# 11  12                   리무진 (Feat. MINO) (Prod. by GRAY)
# 12  13                                          Step Back
# 13  14                                                 서랍
# 14  15                                    strawberry moon
# 15  16                                 그런 밤 (Some Nights)
# 16  17                                          이제 나만 믿어요
# 17  18                    Counting Stars (Feat. Beenzino)
# 18  19                                                신호등
# 19  20                                 다시 사랑한다면 (김필 Ver.)
# 20  21                                               Stay
# 21  22                                            언제나 사랑해
# 22  23                                                겨울잠
# 23  24                               Can't Control Myself
# 24  25                                       별빛 같은 나의 사랑아
# 25  26                                                잊었니
# 26  27                                         Next Level
# 27  28                                            그대라는 사치
# 28  29                                                끝사랑
# 29  30                                               HERO
# 30  31                                            Bk Love
# 31  32                                                 흰눈
# 32  33  만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. by TOIL)
# 33  34                                                 문득
# 34  35                                   Dreams Come True
# 35  36                                     어른아이 (Toddler)
# 36  37                                            Dilemma
# 37  38                                         계단말고 엘리베이터
# 38  39                                         Bad Habits
# 39  40                                     OHAYO MY NIGHT
# 40  41                                     우리가 헤어져야 했던 이유
# 41  42                                             바라만 본다
# 42  43                                             Butter
# 43  44                                     밤하늘의 별을 (2020)
# 44  45                                 Set Myself On Fire
# 45  46                                        My Universe
# 46  47                                             Savage
# 47  48                                                드라마
# 48  49                                           Dynamite
# 49  50                                Permission to Dance
#
#                                가수
# 0                    태연 (TAEYEON)
# 1                에픽하이 (EPIK HIGH)
# 2                      김민석 (멜로망스)
# 3                             임영웅
# 4                              노을
# 5                              탑현
# 6                           GAYLE
# 7                        sokodomo
# 8                      경서예지 & 전건호
# 9                             이무진
# 10                      IVE (아이브)
# 11                      BE'O (비오)
# 12                   GOT the beat
# 13                           10CM
# 14                       아이유 (IU)
# 15                   태연 (TAEYEON)
# 16                            임영웅
# 17                      BE'O (비오)
# 18                            이무진
# 19                            임영웅
# 20  The Kid LAROI & Justin Bieber
# 21                    케이시 (Kassy)
# 22                       아이유 (IU)
# 23                   태연 (TAEYEON)
# 24                            임영웅
# 25                            임영웅
# 26                          aespa
# 27                            임영웅
# 28                            임영웅
# 29                            임영웅
# 30                            임영웅
# 31            먼데이 키즈 (Monday Kiz)
# 32                            베이식
# 33                      BE'O (비오)
# 34                          aespa
# 35                   태연 (TAEYEON)
# 36                   Apink (에이핑크)
# 37                            임영웅
# 38                     Ed Sheeran
# 39           디핵 (D-Hack) & PATEKO
# 40                      비비 (BIBI)
# 41                 MSG워너비 (M.O.M)
# 42                          방탄소년단
# 43                             경서
# 44                   태연 (TAEYEON)
# 45               Coldplay & 방탄소년단
# 46                          aespa
# 47                       아이유 (IU)
# 48                          방탄소년단
# 49                          방탄소년단

# %%
df.to_excel('Genie.xlsx',index = False)
