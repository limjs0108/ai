# %% [markdown]
# <a href="https://colab.research.google.com/github/limjs0108/ai/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
import pandas

# %%
html = requests.get('https://movie.naver.com/movie/sdb/rank/rmovie.naver')

# %%
soup = bs(html.text)

# %%
len(soup.select('tr > td.title'))
# Out:
# 50

# %%
movies = soup.select('tr > td.title')
movies[0]
# Out:
# <td class="title">
# <div class="tit3">
# <a href="/movie/bi/mi/basic.naver?code=191547" title="나일 강의 죽음">나일 강의 죽음</a>
# </div>
# </td>

# %%
title = movies[0].select('div.tit3 > a')[0].text
title
# Out:
# '나일 강의 죽음'

# %%
movie_data = []
rank = 1
for movie in movies:
  title = movie.select('div.tit3 > a')[0].text
  movie_data.append([rank, title])
  rank += 1

movie_data
# Out:
# [[1, '나일 강의 죽음'],
#  [2, '나의 촛불'],
#  [3, '언차티드'],
#  [4, '해적: 도깨비 깃발'],
#  [5, '킹메이커'],
#  [6, '355'],
#  [7, '인민을 위해 복무하라'],
#  [8, '킹스맨: 퍼스트 에이전트'],
#  [9, '스파이더맨: 노 웨이 홈'],
#  [10, '모럴센스'],
#  [11, '극장판 주술회전 0'],
#  [12, '리코리쉬 피자'],
#  [13, '안테벨룸'],
#  [14, '특송'],
#  [15, '더 배트맨'],
#  [16, '스크림'],
#  [17, '굿 보스'],
#  [18, '이상한 나라의 수학자'],
#  [19, '씽2게더'],
#  [20, '대한민국 대통령'],
#  [21, '타짜 전설의 땁'],
#  [22, '하우스 오브 구찌'],
#  [23, '전투왕'],
#  [24, '나이트메어 앨리'],
#  [25, '만년이 지나도 변하지 않는 게 있어'],
#  [26, '듄'],
#  [27, '극장판 안녕 자두야: 제주도의 비밀'],
#  [28, '미싱타는 여자들'],
#  [29, '경관의 피'],
#  [30, '리프레쉬'],
#  [31, '피그'],
#  [32, '셰터드'],
#  [33, '시크릿 카운터'],
#  [34, '문폴'],
#  [35, '쥬라기 월드: 도미니언'],
#  [36, '시라노'],
#  [37, '닥터 스트레인지: 대혼돈의 멀티버스'],
#  [38, '역으로 가는 길을 알려줘'],
#  [39, '장르만 로맨스'],
#  [40, '오리엔트 특급 살인'],
#  [41, '더 마더'],
#  [42, '드라이브 마이 카'],
#  [43, '극장판 바다 탐험대 옥토넛 : 해저동굴 대탈출'],
#  [44, '어나더 라운드'],
#  [45, '뜨거운 피'],
#  [46, '코만도'],
#  [47, '코로나'],
#  [48, '그린 북'],
#  [49, '아웃브레이크 호텔'],
# ...

# %%
import pandas as pd

df = pd.DataFrame(movie_data, columns = ['순위', '타이틀'])
df
# Out:
#     순위                        타이틀
# 0    1                   나일 강의 죽음
# 1    2                      나의 촛불
# 2    3                       언차티드
# 3    4                 해적: 도깨비 깃발
# 4    5                       킹메이커
# 5    6                        355
# 6    7                인민을 위해 복무하라
# 7    8              킹스맨: 퍼스트 에이전트
# 8    9              스파이더맨: 노 웨이 홈
# 9   10                       모럴센스
# 10  11                 극장판 주술회전 0
# 11  12                    리코리쉬 피자
# 12  13                       안테벨룸
# 13  14                         특송
# 14  15                      더 배트맨
# 15  16                        스크림
# 16  17                       굿 보스
# 17  18                이상한 나라의 수학자
# 18  19                       씽2게더
# 19  20                   대한민국 대통령
# 20  21                   타짜 전설의 땁
# 21  22                  하우스 오브 구찌
# 22  23                        전투왕
# 23  24                   나이트메어 앨리
# 24  25        만년이 지나도 변하지 않는 게 있어
# 25  26                          듄
# ...

# %%
df.to_excel('Naver_movies.xlsx',index=False)
